# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/capstonesem2
# Out:
# /content/drive/MyDrive/capstonesem2

# %%
# !git config --global user.name "LePhongCongThanh"

# %%
# !git config --global user.email "lpcthanh1204@gmail.com"

# %%
# !git config --global user.password "Novanchim123"

# %%
git_token = "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"
username = "LePhongCongThanh"
repo = "Predict-Demand-of-Using-Bikes-in-An-Urban"

# %%
# !git clone https://{git_token}@github.com/{username}/{repo}
# Out:
# fatal: destination path 'Predict-Demand-of-Using-Bikes-in-An-Urban' already exists and is not an empty directory.

# %%
ls -la
# Out:
# total 3335
# -rw------- 1 root root     177 Mar 12 15:41  Backup-plan.gdoc
# -rw------- 1 root root   23699 Feb  9 04:39 'Demand forecasting.docx'
# -rw------- 1 root root     177 Mar  9 08:08 'Draft-7 3-Literature Review.gsheet'
# -rw------- 1 root root     177 Apr  9 14:32 'File Câu hỏi .gdoc'
# -rw------- 1 root root 2559039 Jan  5 16:49 'Lect 7 Regression.pptx'
# -rw------- 1 root root  806971 Dec  6 19:27 'Lect 8 Forecasting.pptx'
# drwx------ 3 root root    4096 Apr 10 19:48  Predict-Demand-of-Using-Bikes-in-An-Urban/
# drwx------ 2 root root    4096 Mar  9 08:09 'Preparation Stage'/
# -rw------- 1 root root     177 Mar 12 11:14  Proposals.gdoc
# drwx------ 2 root root    4096 Mar  9 08:09 'Proposal Stage'/
# drwx------ 2 root root    4096 Mar 16 16:29 'Sem 1 22-23'/
# drwx------ 2 root root    4096 Mar 19 16:37 'Thầy Vĩ'/
# -rw------- 1 root root     177 Mar 18 13:38 '[Thy] Objectives, Goals, Problem statement.gdoc'
# ...

# %%
cd Predict-Demand-of-Using-Bikes-in-An-Urban
# Out:
# /content/drive/MyDrive/capstonesem2/Predict-Demand-of-Using-Bikes-in-An-Urban

# %%
# !git status
# Out:
# Refresh index: 100% (3/3), done.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	github.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add Untitled1.ipynb

# %%
# !git commit -m "UPDATED"
# Out:
# [main 59794b6] UPDATED
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled1.ipynb

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/LePhongCongThanh/Predict-Demand-of-Using-Bikes-in-An-Urban (fetch)
# origin	https://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@github.com/LePhongCongThanh/Predict-Demand-of-Using-Bikes-in-An-Urban (push)

# %%
# !git branch
# Out:
# * main

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 4.00 KiB | 683.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/LePhongCongThanh/Predict-Demand-of-Using-Bikes-in-An-Urban
#    bb47f06..59794b6  main -> main

# %%
# !git branch
